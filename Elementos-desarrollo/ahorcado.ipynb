# %%
# evaluacion intermedia 

palabra = 'gata'
p_asterisco = '*' * len(palabra)
vidas = 10

print(palabra)
while vidas > 0 and palabra != p_asterisco:
    letra = input('Letra: ')
    if letra in palabra:
        print('¡Correcto!') 
                p_asterisco = ''.join(letra if letra == ch else p_asterisco[i] for i, ch in enumerate(palabra))
        print(p_asterisco)
    else:
        vidas -= 1
        print(f'¡Esa no está! Tienes {vidas} intentos')
        print(p_asterisco)

if vidas > 0:
    print("¡Has ganado!")
else:
    print("¡Has perdido!")
# Out:
#   File "/tmp/ipykernel_8645/3911943413.py", line 12
#     p_asterisco = ''.join(letra if letra == ch else p_asterisco[i] for i, ch in enumerate(palabra))
#     ^
# IndentationError: unexpected indent

# %%
import random
import string

# %%
l_palabra = ['casa', 'perro', 'cachopo', 'dinosaurio', 'python', 'bucle', 'pesadilla', 'anaconda']
palabra = random.choice(l_palabra)
p_oculta = '_' * len(palabra)
ahorcado = []

vidas = 6

# %%
while vidas > 0 and palabra != p_oculta:
    
    letra = input('Letra:').lower()

    try:
        if letra in string.ascii_lowercase:
            if letra in palabra:
                print('¡Correcto!')
                p_oculta = ''.join(letra if letra == ch else p_oculta[i] for i, ch in enumerate(palabra))
                print(p_oculta)
            else:
                vidas -= 1
                print(f'¡Esa no está! Tienes {vidas} intentos')
                print(p_oculta)
    except:
        print('Dato no válido')
        print('...')
        

if vidas > 0:
    print("¡Has ganado!")
else:
    print("¡Has perdido!")
# Out:
# ¡Correcto!
# a_a____a
# ¡Correcto!
# ana__n_a
# ¡Correcto!
# anac_n_a
# ¡Esa no está! Tienes 5 intentos
# anac_n_a
# ¡Correcto!
# anac_n_a
# ¡Correcto!
# anacon_a
# ¡Correcto!
# anaconda
# ¡Has ganado!

# %%
import random
import string

# %%
l_palabras = ['casa', 'perro', 'cachopo', 'dinosaurio', 'python',
              'bucle', 'pesadilla', 'anaconda', 'lista', 'funcion',
              'variable', 'gato', 'lapiz', 'pez', 'sol', 'clavo',
              'pais', 'oro', 'mesa', 'vaso', 'vino', 'cuadro',
              'elefante', 'estrella', 'universo', 'ventana', 'ordenador',
              'quimera']

palabra_secreta = random.choice(l_palabras)
guiones = "_ " * len(palabra_secreta)
lista_guiones = guiones.split()
vidas = 7
letras_utilizadas = []

# este es para nosotras
intentos = 0
    # --- indice del ahorcado (indice = intentos -1)

# %%
ahorcado =  ['''

+---+
|   |
      |
      |
      |
      |

=========''', '''

  +---+
  |   |
  O   |
      |
      |
      |
=========''', '''

  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', '''

  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''

  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', '''

  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', '''

  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']

# %%
print(ahorcado[0])
# Out:
#           +---+
#           |   |
#               |
#               |
#               |
#               |
#
#         =========

# %%
# JUEGO FUNCIONAL

print('----JUEGO----')
print(f"Intenta adivinar la palabra secreta:")
print(guiones)
print(' ')

while vidas > 0 and guiones.replace(" " , "") != palabra_secreta:
    existe = False # --Variable auxiliar: Determinará si la letra escogida está dentro de la palabra secreta o no
    letra = input("Escoge una letra para adivinar la palabra secreta").strip().lower()
    letras_utilizadas.append(letra)

    for i in range(len(palabra_secreta)):
        if palabra_secreta[i] == letra:
            lista_guiones[i] = letra
            guiones = " ".join(lista_guiones)
            existe = True # --Al cambiar el valor de False a True de la variable auxiliar (existe), indicamos que sí ha encontrado coincidencias durante el bucle de iteraciones
    if existe: # --Si la variable auxiliar (existe) es True, significa que hubo coincidencias con la letra escogida por la jugadora
        print(guiones)
        print(' ')
        print(f"¡Enhorabuena, has acertado! La letra {letra} está en la palabra secreta.")
        print(f"Las letras utilizadas hasta el momento son: {letras_utilizadas}")
        print(' ')
    else:
        vidas -= 1
        intentos += 1
        print(guiones)
        print(' ')
        print(f"Lástima, has fallado. La letra {letra} no se encuentra en la palabra secreta")
        print(f"Te quedan {vidas} vidas")
        print(f"Las letras utilizadas hasta el momento son: {letras_utilizadas}")
        print(ahorcado[intentos-1])
        print(' ')
        
if guiones.replace(' ', '') == palabra_secreta:
    print('CAMPEOOOOOONES')
else:
    print(f'Mala suerte. ¡Perdiste! La palabra era: {palabra_secreta}')
# Out:
# ----JUEGO----
# Intenta adivinar la palabra secreta:
# _ _ _ _
#
# _ _ _ a
#
# ¡Enhorabuena, has acertado! La letra a está en la palabra secreta.
# Las letras utilizadas hasta el momento son: ['a']
#
# _ _ _ a
#
# Lástima, has fallado. La letra o no se encuentra en la palabra secreta
# Te quedan 6 vidas
# Las letras utilizadas hasta el momento son: ['a', 'o']
#
#
#    +---+
#    |   |
#        |
#        |
#        |
#        |
#
# =========
#
# _ e _ a
#
# ¡Enhorabuena, has acertado! La letra e está en la palabra secreta.
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e']
#
# _ e _ a
#
# Lástima, has fallado. La letra n no se encuentra en la palabra secreta
# Te quedan 5 vidas
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n']
#
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# _ e _ a
#
# Lástima, has fallado. La letra c no se encuentra en la palabra secreta
# Te quedan 4 vidas
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n', 'c']
#
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# _ e _ a
#
# Lástima, has fallado. La letra b no se encuentra en la palabra secreta
# Te quedan 3 vidas
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n', 'c', 'b']
#
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
#
# _ e _ a
#
# Lástima, has fallado. La letra l no se encuentra en la palabra secreta
# Te quedan 2 vidas
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n', 'c', 'b', 'l']
#
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# _ e _ a
#
# Lástima, has fallado. La letra t no se encuentra en la palabra secreta
# Te quedan 1 vidas
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n', 'c', 'b', 'l', 't']
#
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# _ e s a
#
# ¡Enhorabuena, has acertado! La letra s está en la palabra secreta.
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n', 'c', 'b', 'l', 't', 's']
#
# m e s a
#
# ¡Enhorabuena, has acertado! La letra m está en la palabra secreta.
# Las letras utilizadas hasta el momento son: ['a', 'o', 'e', 'n', 'c', 'b', 'l', 't', 's', 'm']
#
# CAMPEOOOOOONES

# %%
def banner_juego():
    banner1 = '-----------------------'
    banner2 = '----- EL AHORCADO -----'
    banner3 = 'Intenta adivinar la palabra secreta'
    print(banner1.center(40))
    print(banner2.center(40))
    print(banner1.center(40))
    print(' ')
    print(banner3.center(40))
    print(guiones.center(40))

# %%
banner_juego()
# Out:
#         -----------------------
#         ----- EL AHORCADO -----
#         -----------------------
#
#   Intenta adivinar la palabra secreta
#           _ _ _ _ _ _ _ _ _ _

# %%
def prints_acierto():
    print('* * *'.center(40))
    print(' ')
    print(f"¡Enhorabuena, has acertado! La letra {letra} está en la palabra secreta.")
    print(' ')
    print(guiones.center(40))
    print(' ')
    print(f"Las letras utilizadas hasta el momento son: {letras_utilizadas}")
    print(' ')

# %%
prints_acierto()
# Out:
#
# ¡Enhorabuena, has acertado! La letra a está en la palabra secreta.
#
#           _ _ _ _ _ _ _ _ _ _
#
# Las letras utilizadas hasta el momento son: []

# %%
def prints_error():
    print('* * *'.center(40))
    print(' ')
    print(ahorcado[intentos-1])
    print(guiones.center(40))
    print(' ')
    print(f"Lástima, has fallado. La letra {letra} no se encuentra en la palabra secreta")
    print(f"Te quedan {vidas} vidas")
    print(' ')
    print(f"Las letras utilizadas hasta el momento son: {letras_utilizadas}")
    print(' ')

# %%
prints_error()
# Out:
#
#
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
#           _ _ _ _ _ _ _ _ _ _
#
# Lástima, has fallado. La letra a no se encuentra en la palabra secreta
# Te quedan 7 vidas
#
# Las letras utilizadas hasta el momento son: []
#
#                  * * *

# %%
# funciones para el juego:

banner_juego()
prints_acierto()
prints_error()
# Out:
#         -----------------------
#         ----- EL AHORCADO -----
#         -----------------------
#
#   Intenta adivinar la palabra secreta
#                  _ _ _

# %%
import random

# %%
banner_juego()
# --------------------------------------------- modulo jugar_ahorcado
while vidas > 0 and guiones.replace(" " , "") != palabra_secreta:
    # --------------------------------------------- preparación de juego
    existe = False
    letra = input('Escoge una letra').strip().lower()
    letras_utilizadas.append(letra)
    # ---------------------------------------------
 
    # --------------------------------------------- modulo comprobación palabra
    for i in range(len(palabra_secreta)):
        if palabra_secreta[i] == letra:
            lista_guiones[i] = letra
            guiones = " ".join(lista_guiones)
            existe = True
    # ---------------------------------------------

    # ---------------------------------------------  modulo puntos
    if existe:
        prints_acierto()
    
    else: 
        vidas -= 1
        intentos += 1
        prints_error()
    # ---------------------------------------------

# --------------------------------------------- fin de juego        
if guiones.replace(' ', '') == palabra_secreta:
    print('¡Ganaste!')
else:
    print(f'Mala suerte. ¡Perdiste! La palabra era: {palabra_secreta}')
# ---------------------------------------------
# Out:
#         -----------------------
#         ----- EL AHORCADO -----
#         -----------------------
#
#   Intenta adivinar la palabra secreta
#           _ _ _ _ _ _ _ _ _ _
#
# ¡Enhorabuena, has acertado! La letra a está en la palabra secreta.
#
#           _ _ _ _ _ a _ _ _ _
#
# Las letras utilizadas hasta el momento son: ['a']
#
#
#
#
#    +---+
#    |   |
#        |
#        |
#        |
#        |
#
# =========
#           _ _ _ _ _ a _ _ _ _
#
# Lástima, has fallado. La letra m no se encuentra en la palabra secreta
# Te quedan 6 vidas
#
# Las letras utilizadas hasta el momento son: ['a', 'm']
#
#                  * * *
#
# ¡Enhorabuena, has acertado! La letra d está en la palabra secreta.
#
#           d _ _ _ _ a _ _ _ _
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd']
#
#
# ¡Enhorabuena, has acertado! La letra i está en la palabra secreta.
#
#           d i _ _ _ a _ _ i _
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i']
#
#
#
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#           d i _ _ _ a _ _ i _
#
# Lástima, has fallado. La letra p no se encuentra en la palabra secreta
# Te quedan 5 vidas
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p']
#
#                  * * *
#
#
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#           d i _ _ _ a _ _ i _
#
# Lástima, has fallado. La letra p no se encuentra en la palabra secreta
# Te quedan 4 vidas
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p', 'p']
#
#                  * * *
#
# ¡Enhorabuena, has acertado! La letra n está en la palabra secreta.
#
#           d i n _ _ a _ _ i _
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p', 'p', 'n']
#
#
# ¡Enhorabuena, has acertado! La letra o está en la palabra secreta.
#
#           d i n o _ a _ _ i o
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p', 'p', 'n', 'o']
#
#
# ¡Enhorabuena, has acertado! La letra s está en la palabra secreta.
#
#           d i n o s a _ _ i o
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p', 'p', 'n', 'o', 's']
#
#
# ¡Enhorabuena, has acertado! La letra u está en la palabra secreta.
#
#           d i n o s a u _ i o
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p', 'p', 'n', 'o', 's', 'u']
#
#
# ¡Enhorabuena, has acertado! La letra r está en la palabra secreta.
#
#           d i n o s a u r i o
#
# Las letras utilizadas hasta el momento son: ['a', 'm', 'd', 'i', 'p', 'p', 'n', 'o', 's', 'u', 'r']
#
# ¡Ganaste!
